# %% [markdown]
# # Oefeningen 1.1

# %%
a = 7
b = 2
print(type(a / b), type(a // b))

# VERBETER: zet de tekst om naar een getal:
aantal = "12"
totaal = aantal + 3
assert totaal == 15 and isinstance(totaal, int)
# Out:
# <class 'float'> <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 # VERBETER: zet de tekst om naar een getal:
#       6 aantal = "12"
# ----> 7 totaal = aantal + 3
#       8 assert totaal == 15 and isinstance(totaal, int)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(0.1 + 0.2)
print(0.1 + 0.2 == 0.3)

# VERBETER: vergelijk met een kleine tolerantie:
gelijk = (0.1 + 0.2 == 0.3)
assert gelijk is True
# Out:
# 0.30000000000000004
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 # VERBETER: vergelijk met een kleine tolerantie:
#       5 gelijk = (0.1 + 0.2 == 0.3)
# ----> 6 assert gelijk is True
#
# AssertionError:

# %%
s = "Leuven"
print(s[0], s[-1], len(s))
print("a\tb\nc")

# VERBETER: herstel de aanhalingstekens:
boodschap = "hij zei "hallo""
assert boodschap == 'hij zei "hallo"'
# Out:
#   Cell In[3], line 6
#     boodschap = "hij zei "hallo""
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Oefeningen 1.2

# %%
a = b = 100
a = a + 1
print(a, b)

# VERBETER: zorg dat b ook 101 is (a niet wijzigen):
a = b = 100
# ...
assert a == 101 and b == 101
# Out:
# 101 100
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 6
#       3 print(a, b)
#       5 # VERBETER: zorg dat b ook 101 is (a niet wijzigen):
# ----> 6 assert a == 101 and b == 101
#
# AssertionError:

# %%
x = [1, 2]
y = x
y.append(3)
print(x, y)
print(x is y)

# VERBETER: maak van y een echte kopie:
x = [1, 2]
# ...
assert x == [1, 2] and y == [1, 2, 3]
# Out:
# [1, 2, 3] [1, 2, 3]
# True
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 8
#       5 print(x is y)
#       7 # VERBETER: maak van y een echte kopie:
# ----> 8 assert x == [1, 2] and y == [1, 2, 3]
#
# AssertionError:

# %%
n = "5"
print(n * 2)
n = 5
print(n * 2)

# VERBETER: maak dubbel gelijk aan het getal 10:
invoer = "5"
dubbel = invoer * 2
assert dubbel == 10
# Out:
# 55
# 10
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 9
#       7 invoer = "5"
#       8 dubbel = invoer * 2
# ----> 9 assert dubbel == 10
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.3

# %%
s = {1, 2, 2, 3, 3, 3}
print(len(s))
print(sorted(s))
s.add(2)
print(len(s))

# VERBETER: tel het aantal unieke namen:
namen = ['an', 'bo', 'an', 'cis', 'bo']
aantal_uniek = len(namen)
assert aantal_uniek == 3
# Out:
# 3
# [1, 2, 3]
# 3
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 10
#       8 namen = ['an', 'bo', 'an', 'cis', 'bo']
#       9 aantal_uniek = len(namen)
# ---> 10 assert aantal_uniek == 3
#
# AssertionError:

# %%
l = [10, 20, 30, 40]
print(l[1], l[-1]); print(l[1:3])

# VERBETER: repareer de index (laatste element):
laatste = l[4]
assert laatste == 40
# Out:
# 20 40
# [20, 30]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 print(l[1], l[-1]); print(l[1:3])
#       4 # VERBETER: repareer de index (laatste element):
# ----> 5 laatste = l[4]
#       6 assert laatste == 40
#
# IndexError: list index out of range

# %%
d = {'a': 1, 'b': 2}
print(d['a'], d.get('c'))
print(list(d.keys()), list(d.values()))

# VERBETER: ontbrekende sleutel geeft 0, geen crash:
waarde = d['c']
assert waarde == 0
# Out:
# 1 None
# ['a', 'b'] [1, 2]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 6
#       3 print(list(d.keys()), list(d.values()))
#       5 # VERBETER: ontbrekende sleutel geeft 0, geen crash:
# ----> 6 waarde = d['c']
#       7 assert waarde == 0
#
# KeyError: 'c'

# %% [markdown]
# # Oefeningen 1.4

# %%
print(7 / 2, 7 // 2, 7 % 2, 2 ** 3)
print(-7 // 2, -7 % 2)

# VERBETER: volle dozen van 6 uit 20 stuks, als geheel getal:
dozen = 20 / 6
assert dozen == 3 and isinstance(dozen, int)
# Out:
# 3.5 3 1 8
# -4 1
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 6
#       4 # VERBETER: volle dozen van 6 uit 20 stuks, als geheel getal:
#       5 dozen = 20 / 6
# ----> 6 assert dozen == 3 and isinstance(dozen, int)
#
# AssertionError:

# %%
a = [1, 2]
b = [1, 2]
print(a == b, a is b)
c = a
print(a is c)

# VERBETER: test of de inhoud gelijk is:
zelfde_inhoud = a is b
assert zelfde_inhoud is True
# Out:
# True False
# True
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 9
#       7 # VERBETER: test of de inhoud gelijk is:
#       8 zelfde_inhoud = a is b
# ----> 9 assert zelfde_inhoud is True
#
# AssertionError:

# %%
x = 5
print(0 < x < 10)
print(not x > 3)
print(x > 3 and x < 4 or x == 5)

# VERBETER: x ligt strikt tussen 0 en 10 (syntaxfout):
in_bereik = 0 < x and < 10
assert in_bereik is True
# Out:
#   Cell In[12], line 7
#     in_bereik = 0 < x and < 10
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Oefeningen 1.5

# %%
score = 85
if score >= 60:
    print('geslaagd')
elif score >= 85:
    print('onderscheiding')

# VERBETER: zet de strengste voorwaarde eerst, houd bij in resultaat:
score = 85
# ...
assert resultaat == 'onderscheiding'
# Out:
# geslaagd
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       5     print('onderscheiding')
#       7 # VERBETER: zet de strengste voorwaarde eerst, houd bij in resultaat:
# ----> 8 assert resultaat == 'onderscheiding'
#
# NameError: name 'resultaat' is not defined

# %%
i = 0
while i < 3:
    print(i); i += 1

# VERBETER:  loop doet nog niets:
i = 3
getallen = []
while i > 3:
    pass
assert getallen == [3, 2, 1]
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 10
#       8 while i > 3:
#       9     pass
# ---> 10 assert getallen == [3, 2, 1]
#
# AssertionError:

# %%
for i in range(1, 4):
    print(i, end=' ')
print()
for i, kleur in enumerate(['rood', 'groen']):
    print(i, kleur)

# VERBETER: we willen 1 tot en met 5:
reeks = list(range(1, 5))
assert reeks == [1, 2, 3, 4, 5]
# Out:
# 1 2 3
# 0 rood
# 1 groen
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 9
#       7 # VERBETER: we willen 1 tot en met 5 (off-by-one):
#       8 reeks = list(range(1, 5))
# ----> 9 assert reeks == [1, 2, 3, 4, 5]
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.6

# %%
print([x * x for x in range(5)])
print([x for x in range(10) if x % 3 == 0])

# VERBETER: kwadraten van de even getallen 0 t.e.m. 8:
kwadraten = [x * x for x in range(9)]
assert kwadraten == [0, 4, 16, 36, 64]
# Out:
# [0, 1, 4, 9, 16]
# [0, 3, 6, 9]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 6
#       4 # VERBETER: kwadraten van de even getallen 0 t.e.m. 8:
#       5 kwadraten = [x * x for x in range(9)]
# ----> 6 assert kwadraten == [0, 4, 16, 36, 64]
#
# AssertionError:

# %%
woorden = ['kat', 'hond', 'kat']
print({w for w in woorden})
print({w: len(w) for w in woorden})

# VERBETER: waarde moet de lengte zijn:
woorden = ['kat', 'hond', 'kat']
lengtes = {w: w for w in woorden}
assert lengtes == {'kat': 3, 'hond': 4, 'muis': 4}
# Out:
# {'hond', 'kat'}
# {'kat': 3, 'hond': 4}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 7
#       5 # VERBETER: waarde moet de lengte zijn:
#       6 lengtes = {w: w for w in woorden}
# ----> 7 assert lengtes == {'kat': 3, 'hond': 4, 'muis': 4}
#
# AssertionError:

# %%
resultaat = []
for w in ['an', 'bo', 'cis']:
    resultaat.append(w.upper())
print(resultaat)

# VERBETER: herschrijf als een comprehension:
hoofdletters = []
# ...
assert hoofdletters == ['AN', 'BO', 'CIS']
# Out:
# ['AN', 'BO', 'CIS']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 8
#       6 # VERBETER: herschrijf als één comprehension:
#       7 hoofdletters = []
# ----> 8 assert hoofdletters == ['AN', 'BO', 'CIS']
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.7

# %%
s = "python"
s.upper()
print(s)
t = s.upper(); print(t, s)

# VERBETER: zorg dat naam zelf in hoofdletters staat:
naam = "leuven"
naam.upper()
assert naam == 'LEUVEN'
# Out:
# python
# PYTHON python
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 9
#       7 naam = "leuven"
#       8 naam.upper()
# ----> 9 assert naam == 'LEUVEN'
#
# AssertionError:

# %%
tekst = "a,b,c"
print(tekst.split(","))
print("-".join(tekst.split(",")))

# VERBETER: plak samen met een puntkomma:
samen = delen.join(';')
assert samen == 'a;b;c'
# Out:
# ['a', 'b', 'c']
# a-b-c
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3 print("-".join(tekst.split(",")))
#       5 # VERBETER: plak samen met een puntkomma:
# ----> 6 samen = delen.join(';')
#       7 assert samen == 'a;b;c'
#
# NameError: name 'delen' is not defined

# %%
pi = 3.14159
print(f"{pi:.2f}")
print(f"{pi:10.3f}|")
print("{} is {} jaar".format("An", 20))

# VERBETER: maak het getal exact 2 cijfers na de komma:
bedrag = 12.3456
regel = f"{bedrag}"
assert regel == '12.35'
# Out:
# 3.14
#      3.142|
# An is 20 jaar
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 9
#       7 bedrag = 12.3456
#       8 regel = f"{bedrag}"
# ----> 9 assert regel == '12.35'
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.8

# %%
def dubbel(x):
    print(x * 2)
y = dubbel(3)
print(y)

# VERBETER: pas aan en laat de functie de waarde teruggeven:
def dubbel(x):
    print(x * 2)
assert y == 6
# Out:
# 6
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[37], line 9
#       7 def dubbel(x):
#       8     print(x * 2)
# ----> 9 assert y == 6
#
# AssertionError:

# %%
teller = 0
def verhoog():
    teller = 10
verhoog()
print(teller)

# VERBETER: laat functie iets teruggeven en ken toe (zonder global):
def verhoog(t):
    t = t + 10
assert teller == 10
# Out:
# 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 10
#       8 def verhoog(t):
#       9     t = t + 10
# ---> 10 assert teller == 10
#
# AssertionError:

# %%
def info(naam, jaar=1):
    return naam, jaar
print(info("An"))
print(info(jaar=2, naam="Bo"))

# VERBETER: haal de twee returnwaarden uit elkaar:
n = info("An", 2)
j = None
assert n == 'An' and j == 2
# Out:
# ('An', 1)
# ('Bo', 2)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[24], line 9
#       7 n = info("An", 2)
#       8 j = None
# ----> 9 assert n == 'An' and j == 2
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.9

# %%
getallen = [1, 2, 3, 4, 5, 6]
r = filter(lambda x: x % 2 == 0, getallen)
print(r); print(list(r))

# VERBETER: maak er een echte lijst van:
even = filter(lambda x: x % 2 == 0, getallen)
assert even == [2, 4, 6]
# Out:
# ...
# [2, 4, 6]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 7
#       5 # VERBETER: maak er een echte lijst van:
#       6 even = filter(lambda x: x % 2 == 0, getallen)
# ----> 7 assert even == [2, 4, 6]
#
# AssertionError:

# %%
def kwadraat(x):
    return x * x
print(list(map(kwadraat, [1, 2, 3])))

# VERBETER: pas aan zodat de assert uitkomt:
namen = ['an', 'bo']
groot = map(namen, str.upper)
assert groot == ['AN', 'BO']
# Out:
# [1, 4, 9]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       3 print(list(map(kwadraat, [1, 2, 3])))
#       5 # VERBETER: argumenten staan omgewisseld:
# ----> 6 groot = map(namen, str.upper)
#       7 assert groot == ['AN', 'BO']
#
# TypeError: 'method_descriptor' object is not iterable

# %%
lijst = [1, 2, 3]
it = map(lambda x: x + 1, lijst)
print(list(it))

# VERBETER: maak een map die de getallen vermenigvuldigt met zichzelf
# nieuwe_map = 
assert list(nieuwe_map) == [1, 4, 9]
# Out:
# [2, 3, 4]
# []
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 8
#       6 eerste = list(it)
#       7 tweede = list(it)
# ----> 8 assert eerste == [2, 3, 4] and tweede == [2, 3, 4]
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.10

# %%
class Student:
    def __init__(self, naam, nummer):
        self.naam = naam
        self.nummer = nummer
s = Student('An', 1234)

# VERBETER: maak nieuw student aan:
# ...
assert s.naam == 'Bo' and s.nummer == 4321
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 8
#       5 s = Student('An', 1234)
#       7 # VERBETER: nummer wordt niet opgeslagen:
# ----> 8 assert s.naam == 'Bo' and s.nummer == 4321
#
# AssertionError:

# %%
class Vak:
    def roep():
        return titel.upper()

# VERBETER: pas de class aan zodat de assert uitkomt:
class Vak:
    def roep():
        return titel.upper()
resultaat = Vak.roep()
assert resultaat == 'PYTHON'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[29], line 6
#       3         return titel.upper()
#       5 # VERBETER: de methode mist self:
# ----> 6 assert resultaat == 'PYTHON'
#
# AssertionError:

# %%
class Teller:
    def __init__(self):
        self.n = 0
a = Teller()
b = a
b.n = 5
print(a.n, b.n, a is b)

# VERBETER: a.n moet 0 blijven (in object b):
assert a.n == 0 and b.n == 5
# Out:
# 5 5 True
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[30], line 10
#       7 print(a.n, b.n, a is b)
#       9 # VERBETER: a.n moet 0 blijven (tweede object):
# ---> 10 assert a.n == 0 and b.n == 5
#
# AssertionError:

# %% [markdown]
# # Oefeningen 1.11

# %%
import math
print(math.sqrt(16))
print(math.pi)
print(round(math.pi, 2))

# VERBETER: 
wortel = sqrt(25)
assert wortel == 5.0
# Out:
# 4.0
# 3.141592653589793
# 3.14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       4 print(round(math.pi, 2))
#       6 # VERBETER: sqrt bestaat niet zonder modulenaam:
# ----> 7 wortel = sqrt(25)
#       8 assert wortel == 5.0
#
# NameError: name 'sqrt' is not defined

# %%
from math import pi, sqrt
print(pi, sqrt(9))

# VERBETER: rond 3.7 naar beneden naar beneden:
from math import ceil
naar_beneden = ceil(3.7)
assert naar_beneden == 3
# Out:
# 3.141592653589793 3.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 7
#       5 from math import ceil
#       6 naar_beneden = ceil(3.7)
# ----> 7 assert naar_beneden == 3
#
# AssertionError:

# %%
import math as m
print(m.sqrt(4))

# VERBETER: de eigen variabele overschrijft de module:
import math as m
m = 10
resultaat = m.sqrt(4)
assert resultaat == 2.0
# Out:
# 2.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 7
#       5 import math as m
#       6 m = 10
# ----> 7 resultaat = m.sqrt(4)
#       8 assert resultaat == 2.0
#
# AttributeError: 'int' object has no attribute 'sqrt'

# %% [markdown]
# # Oefeningen 1.12

# %%
getal = 10
print(getal / 0)

# VERBETER: vang de fout op met try/except (en zet de foute lijn hierboven in commentaar):
noemer = 0; boodschap = ''
resultaat = 10 / noemer
assert boodschap == 'delen door 0'
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 getal = 10
# ----> 2 print(getal / 0)
#       4 # VERBETER: vang de fout op met try/except:
#       5 noemer = 0; boodschap = ''
#
# ZeroDivisionError: division by zero

# %%
d = {'a': 1}; l = [1, 2]
try: d['b']
except KeyError as e: print(e)

# VERBETER: loop veilig, totaal moet 6 zijn:
for i in range(len(l) + 1):
    totaal += l[i]
assert totaal == 6
# Out:
# 'b'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 7
#       5 # VERBETER: loop veilig, totaal moet 6 zijn:
#       6 for i in range(len(l) + 1):
# ----> 7     totaal += l[i]
#       8 assert totaal == 6
#
# NameError: name 'totaal' is not defined

# %%
leeftijd = '20'
print(type(leeftijd))
print(leeftijd + 1)

# VERBETER: tel 1 jaar bij de ingelezen leeftijd op:
volgend_jaar = leeftijd + 1
assert volgend_jaar == 21
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 leeftijd = '20'
#       2 print(type(leeftijd))
# ----> 3 print(leeftijd + 1)
#       5 # VERBETER: tel 1 jaar bij de ingelezen leeftijd op:
#       6 volgend_jaar = leeftijd + 1
#
# TypeError: can only concatenate str (not "int") to str
