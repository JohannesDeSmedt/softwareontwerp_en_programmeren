# %% [markdown]
# ## Vraag 1
#
# Bereken de samengestelde interest van een bedrag tegen een bepaald percentage over 10 jaar met een `for`-loop:

# %%
bedrag = 1000
rate = 0.1

# JOUW CODE HIER
# ...
    
print('Finaal bedrag:', bedrag)
# Out:
# Finaal bedrag: 2593.7424601

# %% [markdown]
# ## Vraag 2
#
# Maak een dictionary die per item in een lijst telt hoeveel keer dat het element voorkomt (dus, sleutel = element, waarde = aantal voorkomens in lijst):

# %%
mijn_lijst = [1, 2, 3, 1, 2, 5, 3, 3, 10]
oplossing = {}

# JOUW CODE HIER
# ...

print('Oplossing:', oplossing)
# Out:
# Oplossing: {1: 2, 2: 2, 3: 3, 5: 1, 10: 1}

# %% [markdown]
# ## Vraag 3
#
# Verwijder alle sleutels in een dictionary die een even waarde hebben. Let op, je moet hiervoor eerst de sleutels vinden die verwijderd moeten worden en mag ze dan pas verwijderen:

# %%
woordenboek = {'a': 20, 'b': 13, 'c': 933, 100: 100}

# JOUW CODE HIER
# ...

print('Nieuw woordenboek:', woordenboek)
# Out:
# Nieuw woordenboek: {'b': 13, 'c': 933}

# %% [markdown]
# ## Vraag 4
#
# Er zijn 3 scenario's die moeten bekeken worden, gegeven 3 strings:
# - Als string 1 enkel letters bevat en string 3 zonder white spaces aan de linkerkant enkel letters en cijfers bevat, print 'Scenario 1'
# - Als die conditie niet houdt, check dan of string 2 zonder white spaces aan de linkerkant enkel letters bevat en print 'Scenario 2'
# - Indien die conditie ook niet voldaan is, print 'Scenario 3'.

# %%
def controleer_scenarios(string_1: str, string_2: str, string_3: str) -> str:
    # JOUW CODE HIER
    # ...

string_1 = '7@@hall0'
string_2 = '  lslslssl'
string_3 = 'js$(22!!  '
print('\nControle 1:')
controleer_scenarios(string_1, string_2, string_3)
print('\nControle 2:')
controleer_scenarios(string_1, string_3, string_1)
# Out:
# Controle 1:
# Scenario 2
#
# Controle 2:
# Scenario 3

# %% [markdown]
# ## Vraag 5
#
# Gegeven: een lijst van kommagetallen. Loop door de lijst met een `for`-loop en print de getallen. Rond alle getallen af tot 2 cijfers na de komma en reserveer 10 tekenplaatsen voor het getal:

# %%
getallen_lijst = [0.22, 1.2922, 3993.11112]

# JOUW CODE HIER
# ...
# Out:
# Getal afgerond:       0.22
# Getal afgerond:       1.29
# Getal afgerond:    3993.11

# %% [markdown]
# ## Vraag 6
#
# Draai de volgende string om (in 1 lijn code mbv indexering):

# %%
mijn_string = 'programmeren'

# JOUW CODE HIER
# ...

print(antwoord)
# Out:
# neremmargorp

# %% [markdown]
# Draai de volgende string om met een `for`-lus:

# %%
mijn_string = 'programmeren'
nieuwe_string = ''

# JOUW CODE HIER
# ...

print(nieuwe_string)
# Out:
# neremmargorp
# neremmargorp

# %% [markdown]
# ## Vraag 7
#
# Vind het aantal keer dat 'a' voorkomt in een paswoord zonder gebruik te maken van de count() methode (met een for-loop dus):

# %%
paswoord = 'alakjdaflgkj@LKjaldfkgj;b;b;b;aadfg'

aantal_keer = 0
# JOUW CODE HIER
# ...

print('a komt', aantal_keer, 'voor')
# controle met count()
print('a komt', paswoord.count('a'), 'voor')
# Out:
# a komt 6 voor
# a komt 6 voor

# %% [markdown]
# ## Vraag 8
#
# Voer verschillende controles uit op woorden en print ze anders naar gelang hun inhoud:
# - Als er een 'a' in het woord staat: maak de eerste letter een hoofdletter
# - Als er geen 'a' maar een 'd' in het woord staat, geef dan het aantal 'd's in het woord terug
# - Indien er geen 'a' en 'd' voorkomen, controleer of het woord enkel letters bevat

# %%
woorden = ['programmeren', 'studeren', 'eten', 'herhaal', 'et$en']

for woord in woorden:
    print('Woord:', woord)
    # JOUW CODE HIER
    # ...
# Out:
# Woord: programmeren
# Met hoofdletter aan begin: Programmeren
# Woord: studeren
# Aantal keer dat 'd' voorkomt: 1
# Woord: eten
# Bestaat het woord enkel uit letters? True
# Woord: herhaal
# Met hoofdletter aan begin: Herhaal
# Woord: et$en
# Bestaat het woord enkel uit letters? False

# %% [markdown]
# ## Vraag 9
#
# Stop alle string-gebaseerde en integer-gebaseerde sleutels van een dictionary in aparte dictionaries samen met hun waardes, je kan dit doen door `type()` te gebruiken en de keywords `int` en `str`:

# %%
orginele_dict = {'giovanni': 'pizza', 1: 'pasta', 'windows': 10}
string_dict = {}
int_dict = {}

# JOUW CODE HIER
# ...

print('String dictionary:', string_dict)
print('Integer dictioanry:', int_dict)
# Out:
# String dictionary: {'giovanni': 'pizza', 'windows': 10}
# Integer dictioanry: {1: 'pasta'}

# %% [markdown]
# ## Vraag 10
#
# Zet alle getallen om naar gehele getallen en voeg hun kwadraat toe aan een set:

# %%
lijst_met_getallen = [1, 2.4, 4, 5, 4, 1]
resultaat_set = set()

# JOUW CODE HIER
# ...

print('Resultaat set:', resultaat_set)
# Out:
# Resultaat set: {16, 1, 4, 25}

# %% [markdown]
# ## Vraag 11
#
# Voeg om de 3 plaatsen in een lijst een extra '@' toe (en ook aan het begin):

# %%
lijst = ['b', 'a', 'd', 'e', 'e', 'd', '4', 't', 'y']
lijst.sort()

# JOUW CODE HIER
# ...

print('Uitgebreide lijst:', lijst)
# Out:
# 0
# 3
# 6
# 9
# 12
# Uitgebreide lijst: ['@', '4', 'a', '@', 'b', 'd', '@', 'd', 'e', '@', 'e', 't', '@', 'y']

# %% [markdown]
# ## Vraag 12
#
# Bereken de cosinus van het hoogste getal in een lijst (gebruik hiervoor NumPy).

# %%
import numpy as np

lijst_van_getallen = [0, 10, 4, 29, 3]

# JOUW CODE HIER
# ...
# Out:
# Cosinus hoogste getal (29): -0.75

# %% [markdown]
# ## Vraag 13
#
# Vind het laagste getal in deze matrix (zonder dimensies hard te coderen uiteraard):

# %%
matrix = [[1,2,3,10], [5,2,1,1]]
laagste_getal = 100000

# JOUW CODE HIER
# ...
# overloop rijen
print('Aantal rijen:', len(matrix))
# for i in range(len(matrix)):
# #     print('i:', i)
#     for j in range(len(matrix[i])):
# #         print('j', j)
#         print('elementen:', matrix[i][j])
#         if matrix[i][j] < laagste_getal:
#             laagste_getal = matrix[i][j]

for l, lijst in enumerate(matrix):
    print(l, lijst)
    laagste_in_lijst = min(lijst)
    print(laagste_in_lijst)
#     for element in lijst:
#         print(element)
        

# overloop elementen in rij
#     for
    

print('Laagste getal:', laagste_getal)
# Out:
# Aantal rijen: 2
# 0 [1, 2, 3, 10]
# 1
# 1 [5, 2, 1, 1]
# 1
# Laagste getal: 100000
